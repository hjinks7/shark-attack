# %%
import pandas as pd

# %%
xls = pd.ExcelFile("GSAF5.xls")


df = pd.read_excel(xls)
df.to_csv(f"GSAF5.csv", index=False)

# %%
xls = pd.ExcelFile("country_codes_sharkattack.xlsx")

df = pd.read_excel(xls)
df.to_csv("country_codes_sharkattack.csv", index = False)
